# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from google.colab import files

uploaded = files.upload()
filename = next(iter(uploaded))

df = pd.read_csv(filename)

print("Loaded:", filename)
print("Number of nodes:", len(df))

print("\nColumns:")
print(df.columns.tolist())

print("\nImperfection:")
print("Minimum Delta_r =", df["Delta_r"].min(), "mm")
print("Maximum Delta_r =", df["Delta_r"].max(), "mm")
print("Maximum |Delta_r| =", df["Delta_r"].abs().max(), "mm")

df = df.sort_values(["z_new", "theta_rad"])

z_values = np.sort(df["z_new"].unique())

nodes_per_ring = len(df) // len(z_values)

print("\nNumber of longitudinal rings:", len(z_values))
print("Nodes per circumferential ring:", nodes_per_ring)

X = np.zeros((len(z_values), nodes_per_ring))
Y = np.zeros((len(z_values), nodes_per_ring))
Z = np.zeros((len(z_values), nodes_per_ring))

for i, z_value in enumerate(z_values):

    ring = df[df["z_new"] == z_value].sort_values("theta_rad")

    X[i, :] = ring["x_new"].values
    Y[i, :] = ring["y_new"].values
    Z[i, :] = ring["z_new"].values

fig = go.Figure(
    data=[
        go.Surface(
            x=X,
            y=Y,
            z=Z,
            colorscale="Viridis",
            showscale=False,
            opacity=1.0
        )
    ]
)

fig.update_layout(
    title="3D CHS Imperfection Shape",
    scene=dict(
        xaxis_title="X (mm)",
        yaxis_title="Y (mm)",
        zaxis_title="Z (mm)",
        aspectmode="data"
    ),
    width=1000,
    height=800
)

fig.show()
# Out:
#      <input type="file" id="files-a28d2786-29b8-4816-b07d-552b3da33089" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a28d2786-29b8-4816-b07d-552b3da33089">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
